# %% [raw]
# Notes
#
# Search terms
# Analytics Manager
# Pyspark
# Commercial Analytics
# Databricks
#
#
# Next steps
# Linkedin : Add seperate urls for Director and executive level roles.- Prioritise them -- Problem faced - it takes time to go over jd to find experience
#
# [Done] For the applies - location priority = remote > mumbai > delhi/NCR > pune > bangalore > hyderabad
#
# [Done] write a code to order the dictionary - you provide the list and based on that it takes the urls one by one matching with the text in list.
#
# Add principal business analyst position in search term
# Business analyst 3 and business analyst 4 business analyst II
#
# Lead Business Analyst
#
# Linkedin : Add a filter for last 3 days to reduce.
#
# Companies : Go to glassdoor and extract companies names based on the filer with good rating. extract the data, then you can get the codes for the corresponding companies in from linkedin filters. add a filter of a comapany and its code gets added in the url.
#
# Glassdoor : Add 1001-5001 filter also
#
# Add urls for iimjobs
#
# add urls for arbeitnow
#
# add urls of expertia
#
# add urls for naukri
#
# companies database : create a companies database with the fields such as company name + how large + rating (glassdoor + naukri + ) + ids for naukri etc. you can include the companies from the online list such as top compnaies in so and so domain.
#
# add urls for recommended jobs in linkedin and naukri
#
# add url for profile update in naukri
#
# people find : create urls for finding email and contact info on linkedin and then mail to those people.
# %2E
#
# https://www.linkedin.com/search/results/content/?keywords=(%22hiring%22%20OR%20%22vacancy%22)%20AND%20%22%2Ecom%22%20AND%20(%22analytics%22%20OR%20%22data%22%20OR%20%22analyst%22)&sid=JGE&sortBy=%22date_posted%22
#
#
# https://www.linkedin.com/search/results/content/?authorCompany=%5B%221441%22%2C%221073%22%5D&keywords=(%22hiring%22%20OR%20%22vacancy%22)%20AND%20%22.com%22%20AND%20(%22analytics%22%20OR%20%22data%22%20OR%20%22analyst%22)&origin=FACETED_SEARCH&sid=cK(&sortBy=%22date_posted%22

# %% [markdown]
# ### import libraries

# %%
import os 
import numpy as np 
from bs4 import BeautifulSoup 
import requests
from selenium import webdriver 
import time
from selenium.webdriver.common.by import By 
import pandas as pd 
import random 
import json 
from collections import defaultdict
import ast

# %% [markdown]
# ### functions

# %%
# manage json 
def write_json(data,fname,fpath=None):
    if fpath:
        loc = fpath + '/' + fname + '.json'
    else: 
        loc = os.getcwd()+"/" + fname + '.json'

    with open(loc, 'w') as json_file:
        json.dump(data, json_file)


def read_json(fname,fpath=None):
    if fpath:
        loc = fpath + '/' + fname + '.json'
    else: 
        loc = os.getcwd()+"/" + fname + '.json'

    with open(loc, 'r') as json_file:
        data = json.load(json_file)
        return data

# %%
# current directory
cwd = os.getcwd()+"/"

# %%
def generate_html_with_tiles(url_dict, filename=f'{cwd}tiles.html'):
    # Begin writing the HTML content
    html_content = '''<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>URL Tiles</title>
    <style>
        .tile {
            display: inline-block;
            margin: 10px;
            padding: 20px;
            border: 1px solid #ccc;
            border-radius: 8px;
            background-color: #f9f9f9;
            cursor: pointer;
            text-align: center;
            min-width: 100px;
        }
        .clicked {
            background-color: lightgreen;
        }
    </style>
</head>
<body>
    <div id="tiles-container">
'''

    # Add tiles for each URL
    for display_text, url in url_dict.items():
        html_content += f'''
        <div class="tile" onclick="handleClick(this, '{url}')">
            {display_text}
        </div>
'''

    # Add script to handle clicks and storage
    html_content += '''
    </div>
    <script>
        function handleClick(tile, url) {
            let clickedTiles = JSON.parse(localStorage.getItem('clickedTiles')) || [];
            if (clickedTiles.includes(url)) {
                // If already clicked, remove from clickedTiles and remove clicked class
                clickedTiles = clickedTiles.filter(item => item !== url);
                tile.classList.remove('clicked');
            } else {
                // If not clicked, add to clickedTiles and add clicked class
                clickedTiles.push(url);
                tile.classList.add('clicked');
            }
            localStorage.setItem('clickedTiles', JSON.stringify(clickedTiles));
            window.open(url, '_blank');  // Open the URL in a new tab
        }

        // Mark previously clicked tiles
        window.onload = function() {
            let clickedTiles = JSON.parse(localStorage.getItem('clickedTiles')) || [];
            let tiles = document.querySelectorAll('.tile');
            tiles.forEach(tile => {
                let url = tile.getAttribute('onclick').split("handleClick(this, '")[1].slice(0, -2);
                if (clickedTiles.includes(url)) {
                    tile.classList.add('clicked');
                }
            });
        }
    </script>
</body>
</html>'''

    # Write to the specified HTML file
    with open(filename, 'w') as file:
        file.write(html_content)

# %%
def modify_dict_keys(sort_terms, data):
    # Function to find the lowest index of the matching term in the list
    def get_lowest_index(key):
        for index, term in enumerate(sort_terms):
            if term.lower() in key.lower():
                return index
        return None  # Return None if no match is found

    # Create a new dictionary with modified keys
    modified_dict = {}
    for key in data.keys():
        index = get_lowest_index(key)
        if index is not None:
            # Modify the key to prepend the index
            new_key = f"{index}_{key}"
            modified_dict[new_key] = data[key]
        else:
            # If no match is found, keep the key unchanged
            new_key = f"99_{key}"
            modified_dict[key] = data[key]

    return dict(sorted(modified_dict.items()))

# %% [markdown]
# ### glassdoor urls

# %% [markdown]
# #### glassdoor : url parameters

# %%
glassdoor_urls = {}

# start url 
start = 'https://www.glassdoor.co.in/Job/'

#search term
search_term = {
    'Analytics + India' : 'india-analytics-jobs-SRCH_IL.0,5_IN115_KO6,15.htm?',
    'Analyst + India' : 'india-analyst-jobs-SRCH_IL.0,5_IN115_KO6,13.htm?',
    'Pyspark + India' : 'india-pyspark-jobs-SRCH_IL.0,5_IN115_KO6,13.htm?',
    'Databricks + India' : 'india-databricks-jobs-SRCH_IL.0,5_IN115_KO6,16.htm?',
    'Commercial + Analytics' : 'jobs.htm?sc.occupationParam=commercial%2C+analytics'
}

#rating 
rating = {
'min rating = 3.5' : 'minRating=3.5'
}

#sort
sort = {
'order by date':'sortBy=date_desc'
}

# company size
company_size = {
'>5000 employees':'employerSizes=5'
}

# role position
seniority = {
    'All Seniority levels':'seniorityType=all'
    # ,
    # 'Mid Senior Level':'seniorityType=midseniorlevel',
    # 'Director':'seniorityType=director',
    # 'Executive':'seniorityType=executive'
    
}

# city 
city = {
    'Remote':'&remoteWorkType=1',
    'Mumbai':'cityId=2851180',
    'Gurgaon':'cityId=2921225',
    'Noida':'cityId=4477468'
}

# %%
for search_term_key, search_term_value in search_term.items():
    for rating_key,rating_value in rating.items():
        for company_size_key,company_size_value in company_size.items():
            for seniority_key,seniority_value in seniority.items():
                for city_key,city_value in city.items():
                    url_value = f'{start}{search_term_value}{rating_value}&{sort['order by date']}&{company_size_value}&{seniority_value}&{city_value}'
                    url_key = f'Glassdoor : {search_term_key} + {rating_key} + {company_size_key} + {seniority_key} + {city_key}'
                    glassdoor_urls[url_key] = url_value

# %% [markdown]
# ### linkedin url

# %% [markdown]
# #### linkedin url parameters

# %%
linkedin_urls = {}

#start url 
start = 'https://www.linkedin.com/jobs/search/'

# keyword
keywords = {
    'Analytics and Manager':'keywords=%22Analytics%22%20AND%20%22Manager%22',
    'Business Analyst':'keywords=%22Business%20Analyst%22',
    'Pyspark or databricks':'keywords=%22Pyspark%22%20OR%20%22databricks%22',
    'Commercial and Analytics':'keywords=%22Commercial%22%20AND%20%22Analytics%22'
}

# sort
sort = {
    'order by date':'sortBy=DD'
}


# geography  -- geoID=
geography = {
    'India':'102713980',
    'Worldwide':'92000000',
    'Bengaluru':'105214831',
    'Gurgaon':'104793846',
    'Delhi':'105282602',
    'Mumbai':'106164952',
    'Noida':'104869687',
    'Gurugram':'106442238'    
}

# combination of geography -- for this one the parameter used in the url is f_PP
geography_combination = {
    'India':'&geoId=102713980',
    'Delhi + Gurgaon + Noida + Mumbai' : 'f_PP=106164952%2C106442238%2C104793846%2C104869687%2C105282602',
    'Remote - India' : 'f_WT=2&geoId=102713980',
    'Bengaluru':'f_PP=105214831'
}


job_age = {
    '3 days':'f_TPR=r302400'
}

# %%
for keywords_key, keywords_value in keywords.items():
    for geography_combination_key, geography_combination_value in geography_combination.items():
        for job_age_key,job_age_value in job_age.items():
            
            url_key = f'linkedin : {keywords_key} + {geography_combination_key} + {job_age_key}'
            url_value = f'{start}?{sort['order by date']}&{geography_combination_value}&{job_age_value}&{keywords_value}'
            linkedin_urls[url_key] = url_value

# %% [markdown]
# ### naurki urls

# %%
naukri_urls = {}

#start url 
start = 'https://www.naukri.com/'

#skills
skills = {
    'data analysis': 'data-analysis-jobs',
    'analytical': 'analytical-jobs',
    'business intelligence': 'business-intelligence-jobs',
    'business reporting': 'business-reporting-jobs',
    'data visualization': 'data-visualization-jobs',
    'pyspark': 'pyspark-jobs',
    'python spark': 'python-spark-jobs',
    'panda': 'panda-jobs',
    'azure data factory': 'azure-data-factory-jobs',
    'azure databricks': 'azure-databricks-jobs',
    'data engineering': 'data-engineering-jobs',
    'business analyst': 'business-analyst-jobs',
    'analytics manager': 'analytics-manager-jobs'
}

#keywords
keywords = {
    
}
#ctc 

ctc = { '> 25lpa' : '&ctcFilter=501&ctcFilter=25to50&ctcFilter=50to75&ctcFilter=75to100&ctcFilter=100to500

# %% [markdown]
# ### creating html file

# %%
url_dict = {**linkedin_urls, **glassdoor_urls}

# location sort
sort_terms = ['remote','mumbai','gurugram','gurgaon','noida','bangalore','bengaluru','india']
url_dict = modify_dict_keys(sort_terms,url_dict)


# job apply location sort 
sort_terms = ['linkedin','glassdoor']
url_dict = modify_dict_keys(sort_terms,url_dict)

# %%
# url_dict
generate_html_with_tiles(url_dict)
